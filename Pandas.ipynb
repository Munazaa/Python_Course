# %% [markdown]
# # Pandas tutorial (Day-11)
#
# ## This notebook explains:
# 1-

# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#object creation (like make a series and understanding of pandas defined functions)
s= pd.Series([1,2,3,4,np.nan,5]) #nan represet empty cell
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    NaN
# 5    5.0
# dtype: float64

# %%
date= pd.date_range("20150101", periods=6) #how to create date series using pd.date
date
# Out:
# DatetimeIndex(['2015-01-01', '2015-01-02', '2015-01-03', '2015-01-04',
#                '2015-01-05', '2015-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
date= pd.date_range("20150101", periods=6) #dataframe mean like an excelsheet creation
df=pd.DataFrame(np.random.randn(6,4), index=date, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2015-01-01 -0.294337  0.178182 -1.673022 -0.537176
# 2015-01-02 -0.149059 -1.785379  1.192904  0.731790
# 2015-01-03 -1.996387 -0.974841 -0.273624 -0.504107
# 2015-01-04  0.729100  0.080074  0.456465 -0.404940
# 2015-01-05 -2.461540  0.266605 -0.581373 -0.732954
# 2015-01-06  1.329315  0.144779 -0.891456  0.481366

# %%
#how to make like dictionary  #data fram dictionary
df2= pd.DataFrame(
    {
        "a":1.0,
        "b":pd.Timestamp("20150102"),
        "c":pd.Series(1, index=list(range(5)), dtype="float32"),
        "d":np.array([3]*5, dtype="int32"),
        "e":pd.Categorical(["girl","women","men","boy","child"]),
        "f":"Gender",
        
    }

)

# %%
df2
# Out:
#      a          b    c  d      e       f
# 0  1.0 2015-01-02  1.0  3   girl  Gender
# 1  1.0 2015-01-02  1.0  3  women  Gender
# 2  1.0 2015-01-02  1.0  3    men  Gender
# 3  1.0 2015-01-02  1.0  3    boy  Gender
# 4  1.0 2015-01-02  1.0  3  child  Gender

# %%
df2.dtypes
# Out:
# a           float64
# b    datetime64[ns]
# c           float32
# d             int32
# e          category
# f            object
# dtype: object

# %%
df.head(2) #showing start of data
# Out:
#                    A         B         C         D
# 2015-01-01 -0.294337  0.178182 -1.673022 -0.537176
# 2015-01-02 -0.149059 -1.785379  1.192904  0.731790

# %%
df.tail(2) #showing last part of data
# Out:
#                    A         B         C         D
# 2015-01-05 -2.461540  0.266605 -0.581373 -0.732954
# 2015-01-06  1.329315  0.144779 -0.891456  0.481366

# %%
df2.index #index
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')

# %%
df2.to_numpy() #converting into array
# Out:
# array([[1.0, Timestamp('2015-01-02 00:00:00'), 1.0, 3, 'girl', 'Gender'],
#        [1.0, Timestamp('2015-01-02 00:00:00'), 1.0, 3, 'women', 'Gender'],
#        [1.0, Timestamp('2015-01-02 00:00:00'), 1.0, 3, 'men', 'Gender'],
#        [1.0, Timestamp('2015-01-02 00:00:00'), 1.0, 3, 'boy', 'Gender'],
#        [1.0, Timestamp('2015-01-02 00:00:00'), 1.0, 3, 'child', 'Gender']],
#       dtype=object)

# %%
df2.describe() #calculatinf statitics
# Out:
#          a    c    d
# count  5.0  5.0  5.0
# mean   1.0  1.0  3.0
# std    0.0  0.0  0.0
# min    1.0  1.0  3.0
# 25%    1.0  1.0  3.0
# 50%    1.0  1.0  3.0
# 75%    1.0  1.0  3.0
# max    1.0  1.0  3.0

# %%
df2.T #transpose
# Out:
#                      0                    1                    2  \
# a                    1                    1                    1
# b  2015-01-02 00:00:00  2015-01-02 00:00:00  2015-01-02 00:00:00
# c                    1                    1                    1
# d                    3                    3                    3
# e                 girl                women                  men
# f               Gender               Gender               Gender
#
#                      3                    4
# a                    1                    1
# b  2015-01-02 00:00:00  2015-01-02 00:00:00
# c                    1                    1
# d                    3                    3
# e                  boy                child
# f               Gender               Gender

# %%
df2.sort_index(axis=0, ascending=True) #ascending and decsing order
# Out:
#      a          b    c  d      e       f
# 0  1.0 2015-01-02  1.0  3   girl  Gender
# 1  1.0 2015-01-02  1.0  3  women  Gender
# 2  1.0 2015-01-02  1.0  3    men  Gender
# 3  1.0 2015-01-02  1.0  3    boy  Gender
# 4  1.0 2015-01-02  1.0  3  child  Gender

# %%
##importing dataset
data=pd.read_csv("Chilla_data2.csv")
data.head()
# Out:
#    Gender  Location    Age Qualification_completed    field_of_study  \
# 0    Male  Pakistan  36-40                 Masters  Natural Sciences
# 1    Male  Pakistan  26-30               Bachelors             CS/IT
# 2    Male  Pakistan  31-35                 Masters       Enginnering
# 3  Female  Pakistan  31-35                 Masters             CS/IT
# 4  Female  Pakistan  26-30                 Masters       Enginnering
#
#          Purpose_for_chilla What are you? Blood group   \
# 0     to boost my skill set     Unemplyed           B+
# 1     to boost my skill set       Student           B+
# 2  Switch my field of study      Employed           B+
# 3     to boost my skill set      Employed           O+
# 4     to boost my skill set       Student           A-
#
#   Which mobile sim do you use Prepaid or Postpaid  ...  \
# 0                      U-fone             Prepaid  ...
# 1                      U-fone             Prepaid  ...
# ...

# %%
data.sort_index(axis=1, ascending=False)
# Out:
#        field_of_study Your favorite programming language?  \
# 0    Natural Sciences                              Python
# 1               CS/IT                              Python
# 2         Enginnering                              Python
# 3               CS/IT                              Python
# 4         Enginnering                          Javascript
# ..                ...                                 ...
# 370       Enginnering                                   R
# 371       Enginnering                              Python
# 372             CS/IT                              Python
# 373       Enginnering                              Python
# 374       Mathematics                              Python
#
#      Your Weight in kg? (float) Which mobile sim do you use  \
# 0                          77.0                      U-fone
# 1                          53.6                      U-fone
# 2                          93.0                        Zong
# ...

# %%
data.T #transpose on chilla_class data
# Out:
#                                                                    0    \
# Gender                                                            Male
# Location                                                      Pakistan
# Age                                                              36-40
# Qualification_completed                                        Masters
# field_of_study                                        Natural Sciences
# Purpose_for_chilla                               to boost my skill set
# What are you?                                                Unemplyed
# Blood group                                                         B+
# Which mobile sim do you use                                     U-fone
# Prepaid or Postpaid                                            Prepaid
# Which PC are you using?                                    Apna Laptop
# Do you wear glasses?                                                No
# ...

# %%
#row wise selection
data[0:4]
# Out:
#    Gender  Location    Age Qualification_completed    field_of_study  \
# 0    Male  Pakistan  36-40                 Masters  Natural Sciences
# 1    Male  Pakistan  26-30               Bachelors             CS/IT
# 2    Male  Pakistan  31-35                 Masters       Enginnering
# 3  Female  Pakistan  31-35                 Masters             CS/IT
#
#          Purpose_for_chilla What are you? Blood group   \
# 0     to boost my skill set     Unemplyed           B+
# 1     to boost my skill set       Student           B+
# 2  Switch my field of study      Employed           B+
# 3     to boost my skill set      Employed           O+
#
#   Which mobile sim do you use Prepaid or Postpaid  ...  \
# 0                      U-fone             Prepaid  ...
# 1                      U-fone             Prepaid  ...
# 2                        Zong             Prepaid  ...
# 3                      U-fone            Postpaid  ...
#
# ...

# %%
data.loc [:,["Age", "Location"]] #columnwisw section
# Out:
#        Age  Location
# 0    36-40  Pakistan
# 1    26-30  Pakistan
# 2    31-35  Pakistan
# 3    31-35  Pakistan
# 4    26-30  Pakistan
# ..     ...       ...
# 370  26-30  Pakistan
# 371  31-35  Pakistan
# 372  21-25  Pakistan
# 373  26-30  Pakistan
# 374  31-35  Pakistan
#
# [375 rows x 2 columns]

# %%
##importing  FAO dataset
LU=pd.read_csv("FAO_LU_comparison.csv")
LU.head(4)
# Out:
#   Domain Code    Domain  Area Code (FAO)      Area  Element Code Element  \
# 0          RL  Land Use               32  Cameroon          5110    Area
# 1          RL  Land Use               32  Cameroon          5110    Area
# 2          RL  Land Use               32  Cameroon          5110    Area
# 3          RL  Land Use               32  Cameroon          5110    Area
#
#    Item Code          Item  Year Code  Year     Unit    Value Flag  \
# 0       6600  Country area       1961  1961  1000 ha  47544.0    Q
# 1       6600  Country area       1962  1962  1000 ha  47544.0    Q
# 2       6600  Country area       1963  1963  1000 ha  47544.0    Q
# 3       6600  Country area       1964  1964  1000 ha  47544.0    Q
#
#                                     Flag Description
# 0  Official data reported on FAO Questionnaires f...
# 1  Official data reported on FAO Questionnaires f...
# 2  Official data reported on FAO Questionnaires f...
# ...

# %%
LU.dtypes
# Out:
# Domain Code          object
# Domain               object
# Area Code (FAO)       int64
# Area                 object
# Element Code          int64
# Element              object
# Item Code             int64
# Item                 object
# Year Code             int64
# Year                  int64
# Unit                 object
# Value               float64
# Flag                 object
# Flag Description     object
# dtype: object

# %%
LU.loc [:,["Area", "Item"]]
# Out:
#           Area                                 Item
# 0     Cameroon                         Country area
# 1     Cameroon                         Country area
# 2     Cameroon                         Country area
# 3     Cameroon                         Country area
# 4     Cameroon                         Country area
# ...        ...                                  ...
# 2152  Pakistan  Agriculture area actually irrigated
# 2153  Pakistan  Agriculture area actually irrigated
# 2154  Pakistan  Agriculture area actually irrigated
# 2155  Pakistan  Agriculture area actually irrigated
# 2156  Pakistan  Agriculture area actually irrigated
#
# [2157 rows x 2 columns]

# %%
LU.iloc[3] #specific position data
# Out:
# Domain Code                                                        RL
# Domain                                                       Land Use
# Area Code (FAO)                                                    32
# Area                                                         Cameroon
# Element Code                                                     5110
# Element                                                          Area
# Item Code                                                        6600
# Item                                                     Country area
# Year Code                                                        1964
# Year                                                             1964
# Unit                                                          1000 ha
# Value                                                           47544
# Flag                                                                Q
# ...

# %%
LU.iloc[0:5,0:3] #rows to column data filter
# Out:
#   Domain Code    Domain  Area Code (FAO)
# 0          RL  Land Use               32
# 1          RL  Land Use               32
# 2          RL  Land Use               32
# 3          RL  Land Use               32
# 4          RL  Land Use               32

# %%
LU[LU["Year"]>2000] #Boolean operators in pandas
# Out:
#      Domain Code    Domain  Area Code (FAO)      Area  Element Code Element  \
# 40            RL  Land Use               32  Cameroon          5110    Area
# 41            RL  Land Use               32  Cameroon          5110    Area
# 42            RL  Land Use               32  Cameroon          5110    Area
# 43            RL  Land Use               32  Cameroon          5110    Area
# 44            RL  Land Use               32  Cameroon          5110    Area
# ...          ...       ...              ...       ...           ...     ...
# 2152          RL  Land Use              165  Pakistan          5110    Area
# 2153          RL  Land Use              165  Pakistan          5110    Area
# 2154          RL  Land Use              165  Pakistan          5110    Area
# 2155          RL  Land Use              165  Pakistan          5110    Area
# 2156          RL  Land Use              165  Pakistan          5110    Area
#
# ...

# %%
LU_PAK=LU[LU["Area"]=="Pakistan"]
LU_PAK
# Out:
#      Domain Code    Domain  Area Code (FAO)      Area  Element Code Element  \
# 1694          RL  Land Use              165  Pakistan          5110    Area
# 1695          RL  Land Use              165  Pakistan          5110    Area
# 1696          RL  Land Use              165  Pakistan          5110    Area
# 1697          RL  Land Use              165  Pakistan          5110    Area
# 1698          RL  Land Use              165  Pakistan          5110    Area
# ...          ...       ...              ...       ...           ...     ...
# 2152          RL  Land Use              165  Pakistan          5110    Area
# 2153          RL  Land Use              165  Pakistan          5110    Area
# 2154          RL  Land Use              165  Pakistan          5110    Area
# 2155          RL  Land Use              165  Pakistan          5110    Area
# 2156          RL  Land Use              165  Pakistan          5110    Area
#
# ...

# %%
LU[LU["Year"]<2000]
# Out:
#      Domain Code    Domain  Area Code (FAO)      Area  Element Code Element  \
# 0             RL  Land Use               32  Cameroon          5110    Area
# 1             RL  Land Use               32  Cameroon          5110    Area
# 2             RL  Land Use               32  Cameroon          5110    Area
# 3             RL  Land Use               32  Cameroon          5110    Area
# 4             RL  Land Use               32  Cameroon          5110    Area
# ...          ...       ...              ...       ...           ...     ...
# 2113          RL  Land Use              165  Pakistan          5110    Area
# 2114          RL  Land Use              165  Pakistan          5110    Area
# 2115          RL  Land Use              165  Pakistan          5110    Area
# 2116          RL  Land Use              165  Pakistan          5110    Area
# 2117          RL  Land Use              165  Pakistan          5110    Area
#
# ...

# %%
mean1 = LU['Value'].mean() #mean function
mean1
# Out:
# 19435.188111914635

# %%
mean2 = LU_PAK['Value'].mean() #mean function
mean2
# Out:
# 34583.710480561575
